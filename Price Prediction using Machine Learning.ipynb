# %% [markdown]
# # Price Prediction using Machine Learning

# %% [markdown]
# # 1- Import data  :

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set()
import re

# %%
df=pd.read_csv("data_laptop_clean")
df.head(5)
# Out:
#   Company   TypeName  Inches            Cpu  Ram  Memory         Gpu  OpSys  \
# 0   Apple  Ultrabook    13.3  Intel Core i5    8   128.0  Intel Iris     OS
# 1   Apple  Ultrabook    13.3  Intel Core i5    8   128.0    Intel HD     OS
# 2      HP   Notebook    15.6  Intel Core i5    8   256.0    Intel HD  No OS
# 3   Apple  Ultrabook    15.4  Intel Core i7   16   512.0  AMD Radeon     OS
# 4   Apple  Ultrabook    13.3  Intel Core i5    8   256.0  Intel Iris     OS
#
#    Weight        Price IPS/Touchscreen  width  height  Memory_plusCapacite  \
# 0    1.37   71378.6832             IPS   2560    1600                  0.0
# 1    1.34   47895.5232     Touchscreen   1440     900                  0.0
# 2    1.86   30636.0000     Touchscreen   1920    1080                  0.0
# 3    1.83  135195.3360             IPS   2880    1800                  0.0
# 4    1.37   96095.8080             IPS   2560    1600                  0.0
#
#   Mermory_plusType Mermory_Type
# 0              Any          SSD
# 1              Any        Flash
# 2              Any          SSD
# 3              Any          SSD
# 4              Any          SSD

# %% [markdown]
# # 2 Split data

# %% [markdown]
# Splitting the data into an **output**, which is the **price**, and **inputs**, which are the remaining columns.
# Additionally, the data will be divided into a **training set** and a **testing set**.

# %%
X = df[['Company', 'TypeName', 'Inches', 'Cpu', 'Ram', 'Memory', 'Gpu', 'OpSys',
       'Weight', 'Memory_plusCapacite', 'Mermory_plusType',
       'Mermory_Type', 'IPS/Touchscreen', 'width', 'height']]
y = df['Price']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %% [markdown]
# The columns will be divided into **those with numerical values** and **those with textual values**.

# %%
numeric_features = ['Inches', 'Ram', 'Memory','Weight', 'Memory_plusCapacite', 'width', 'height']
categorical_features = ['Company', 'TypeName', 'Cpu','Gpu', 'OpSys','Mermory_plusType','Mermory_Type', 'IPS/Touchscreen']

# %%
# Import package sklearn
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder

# %%
# Create Pipeline 
num_pipeline=Pipeline(steps=[
    ("inpute",SimpleImputer(strategy="mean")),
    ("scale",StandardScaler())
])
cat_pipeline=Pipeline(steps=[
    ("inpute",SimpleImputer(strategy="most_frequent")),
    ("one-hot-encoder",OneHotEncoder(handle_unknown='ignore'))
])

# %%
# Create preprocessor

preprocessor=ColumnTransformer(transformers=[
    ('num_pipeline',num_pipeline,numeric_features),
    ('cat_pipeline',cat_pipeline,categorical_features)
 ])

# %%
# Import package Models regrssion 
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor ,GradientBoostingRegressor
from sklearn.linear_model import Ridge ,Lasso ,ElasticNet,LinearRegression

# %%
# Grouping Models 
models = {
    'lg': LinearRegression(),
    'rd': Ridge(),
    'ls': Lasso(max_iter=5000),
    'en': ElasticNet(max_iter=10000),
    'svr': SVR(),
    'dtg': DecisionTreeRegressor(),
    'rfr': RandomForestRegressor(),
    'gbr': GradientBoostingRegressor()
}
for key, value in models.items():
    print(f"{key} = {value.__class__.__name__}()")
# Out:
# lg = LinearRegression()
# rd = Ridge()
# ls = Lasso()
# en = ElasticNet()
# svr = SVR()
# dtg = DecisionTreeRegressor()
# rfr = RandomForestRegressor()
# gbr = GradientBoostingRegressor()

# %%
# Hyperparameters Tuning
param_grids = {
    'lg': {},
    'rd': {
        'cls__alpha': [0.01, 0.1, 1, 10]},  # معلمات Ridge
    'ls': {
        'cls__alpha': [0.01, 0.1, 1, 10]},  # معلمات Lasso
    'en':{
        'cls__alpha': [0.01, 0.1, 1, 10, 100],
        'cls__l1_ratio': [0.1, 0.5, 0.7, 0.9, 1]},  # معلمات ElasticNet
    'svr': {
        'cls__C': [1, 2, 3],
        'cls__epsilon': [0.5, 1.0, 1.5]},  # معلمات SVR
    'dtg': {
        'cls__max_depth': [3, 5, 10, None],
        'cls__min_samples_split': [2, 5, 10],
       # 'cls__min_samples_leaf': [1, 2, 4],
       # 'cls__max_features': [None, 'sqrt', 'log2'],
        #'cls__criterion': ['squared_error', 'friedman_mse', 'absolute_error']
    }, 
    'rfr': {
        'cls__n_estimators': [50, 100, 200],
        'cls__max_depth': [None, 10, 20, 30],
        'cls__min_samples_split': [2, 5, 10],
        #'cls__min_samples_leaf': [1, 2, 4],
        #'cls__max_features': ['sqrt', 'log2'],
        #'cls__bootstrap': [True, False],
        #'cls__criterion': ['squared_error', 'friedman_mse', 'absolute_error', 'poisson']
        },  
    'gbr': {
        'cls__n_estimators': [50, 100, 200],
        'cls__learning_rate': [0.01, 0.1, 0.2],
        'cls__max_depth': [3, 5, 10],
        #'cls__min_samples_split': [2, 5, 10],
        #'cls__min_samples_leaf': [1, 2, 4],
        #'cls__subsample': [0.8, 1.0],
        #'cls__loss': ['squared_error', 'absolute_error'],
        #'cls__max_features': ['sqrt', 'log2'],
        #'cls__warm_start': [True, False]
    }  
}

# %% [markdown]
# # Model Re-Building

# %% [markdown]
# **Model LinearRegression()  'lg'**

# %%
#Create Pipepline with model linear regression 
pipeline = Pipeline(steps=[
    ('preprocessor', preprocessor),
    
    ('cls', models['lg'])])

# %%
pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num_pipeline',
#                                                   Pipeline(steps=[('inpute',
#                                                                    SimpleImputer()),
#                                                                   ('scale',
#                                                                    StandardScaler())]),
#                                                   ['Inches', 'Ram', 'Memory',
#                                                    'Weight',
#                                                    'Memory_plusCapacite',
#                                                    'width', 'height']),
#                                                  ('cat_pipeline',
#                                                   Pipeline(steps=[('inpute',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('one-hot-encoder',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['Company', 'TypeName', 'Cpu',
#                                                    'Gpu', 'OpSys',
#                                                    'Mermory_plusType',
#                                                    'Mermory_Type',
#                                                    'IPS/Touchscreen'])])),
#                 ('cls', LinearRegression())])

# %%
param_grid = param_grids['lg']

# %%
from sklearn.model_selection import GridSearchCV

# %%
grid = GridSearchCV(pipeline, param_grid=param_grid, cv=5)

# %%
grid.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(transformers=[('num_pipeline',
#                                                                          Pipeline(steps=[('inpute',
#                                                                                           SimpleImputer()),
#                                                                                          ('scale',
#                                                                                           StandardScaler())]),
#                                                                          ['Inches',
#                                                                           'Ram',
#                                                                           'Memory',
#                                                                           'Weight',
#                                                                           'Memory_plusCapacite',
#                                                                           'width',
#                                                                           'height']),
#                                                                         ('cat_pipeline',
#                                                                          Pipeline(steps=[('inpute',
#                                                                                           SimpleImputer(strategy='most_frequent')),
#                                                                                          ('one-hot-encoder',
#                                                                                           OneHotEncoder(handle_unknown='ignore'))]),
#                                                                          ['Company',
#                                                                           'TypeName',
#                                                                           'Cpu',
#                                                                           'Gpu',
#                                                                           'OpSys',
#                                                                           'Mermory_plusType',
#                                                                           'Mermory_Type',
#                                                                           'IPS/Touchscreen'])])),
#                                        ('cls', LinearRegression())]),
#              param_grid={})

# %%
y_pred = grid.predict(X_test)

# %%
# Evalution model
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

# %%
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)

# %%
eval_linearRegression=[mse , rmse ,r2 , mae]

# %% [markdown]
# **Model Ridge() 'rd'**

# %%
#Create Pipepline with model ridge
pipeline = Pipeline(steps=[
    ('preprocessor', preprocessor),
    
    ('cls', models['rd'])])

# %%
pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num_pipeline',
#                                                   Pipeline(steps=[('inpute',
#                                                                    SimpleImputer()),
#                                                                   ('scale',
#                                                                    StandardScaler())]),
#                                                   ['Inches', 'Ram', 'Memory',
#                                                    'Weight',
#                                                    'Memory_plusCapacite',
#                                                    'width', 'height']),
#                                                  ('cat_pipeline',
#                                                   Pipeline(steps=[('inpute',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('one-hot-encoder',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['Company', 'TypeName', 'Cpu',
#                                                    'Gpu', 'OpSys',
#                                                    'Mermory_plusType',
#                                                    'Mermory_Type',
#                                                    'IPS/Touchscreen'])])),
#                 ('cls', Ridge())])

# %%
param_grid = param_grids['rd']

# %%
grid = GridSearchCV(pipeline, param_grid=param_grid, cv=5)

# %%
grid.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(transformers=[('num_pipeline',
#                                                                          Pipeline(steps=[('inpute',
#                                                                                           SimpleImputer()),
#                                                                                          ('scale',
#                                                                                           StandardScaler())]),
#                                                                          ['Inches',
#                                                                           'Ram',
#                                                                           'Memory',
#                                                                           'Weight',
#                                                                           'Memory_plusCapacite',
#                                                                           'width',
#                                                                           'height']),
#                                                                         ('cat_pipeline',
#                                                                          Pipeline(steps=[('inpute',
#                                                                                           SimpleImputer(strategy='most_frequent')),
#                                                                                          ('one-hot-encoder',
#                                                                                           OneHotEncoder(handle_unknown='ignore'))]),
#                                                                          ['Company',
#                                                                           'TypeName',
#                                                                           'Cpu',
#                                                                           'Gpu',
#                                                                           'OpSys',
#                                                                           'Mermory_plusType',
#                                                                           'Mermory_Type',
#                                                                           'IPS/Touchscreen'])])),
#                                        ('cls', Ridge())]),
#              param_grid={'cls__alpha': [0.01, 0.1, 1, 10]})

# %%
best_model_rd = grid.best_estimator_

# %%
best_model_rd
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num_pipeline',
#                                                   Pipeline(steps=[('inpute',
#                                                                    SimpleImputer()),
#                                                                   ('scale',
#                                                                    StandardScaler())]),
#                                                   ['Inches', 'Ram', 'Memory',
#                                                    'Weight',
#                                                    'Memory_plusCapacite',
#                                                    'width', 'height']),
#                                                  ('cat_pipeline',
#                                                   Pipeline(steps=[('inpute',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('one-hot-encoder',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['Company', 'TypeName', 'Cpu',
#                                                    'Gpu', 'OpSys',
#                                                    'Mermory_plusType',
#                                                    'Mermory_Type',
#                                                    'IPS/Touchscreen'])])),
#                 ('cls', Ridge(alpha=10))])

# %%
y_pred = best_model_rd.predict(X_test)

# %%
# Evalution Model
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)

# %%
eval_ridge=[mse , rmse ,r2 , mae]

# %% [markdown]
# **Model ElasticNet() 'en'**

# %%
#Create Pipepline with model ElasticNet
pipeline = Pipeline(steps=[
    ('preprocessor', preprocessor),
    
    ('cls', models['en'])])

# %%
pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num_pipeline',
#                                                   Pipeline(steps=[('inpute',
#                                                                    SimpleImputer()),
#                                                                   ('scale',
#                                                                    StandardScaler())]),
#                                                   ['Inches', 'Ram', 'Memory',
#                                                    'Weight',
#                                                    'Memory_plusCapacite',
#                                                    'width', 'height']),
#                                                  ('cat_pipeline',
#                                                   Pipeline(steps=[('inpute',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('one-hot-encoder',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['Company', 'TypeName', 'Cpu',
#                                                    'Gpu', 'OpSys',
#                                                    'Mermory_plusType',
#                                                    'Mermory_Type',
#                                                    'IPS/Touchscreen'])])),
#                 ('cls', ElasticNet(max_iter=10000))])

# %%
param_grid = param_grids['en']

# %%
grid = GridSearchCV(pipeline, param_grid=param_grid, cv=5)

# %%
grid.fit(X_train, y_train)
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:589: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 28733489403.05977, tolerance: 101170713.21856582
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:589: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 47601054375.32968, tolerance: 95346379.33399342
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:589: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 27499248012.974487, tolerance: 95188419.86920427
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:589: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 44798309377.18902, tolerance: 93051732.8854233
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:589: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 26273837001.161896, tolerance: 99014352.60986783
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:589: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 18414687649.758057, tolerance: 101170713.21856582
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:589: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 17143298301.304626, tolerance: 95346379.33399342
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:589: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 17805157466.734436, tolerance: 95188419.86920427
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:589: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 15467790750.519882, tolerance: 93051732.8854233
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:589: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7347374032.098297, tolerance: 99014352.60986783
#   model = cd_fast.sparse_enet_coordinate_descent(
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(transformers=[('num_pipeline',
#                                                                          Pipeline(steps=[('inpute',
#                                                                                           SimpleImputer()),
#                                                                                          ('scale',
#                                                                                           StandardScaler())]),
#                                                                          ['Inches',
#                                                                           'Ram',
#                                                                           'Memory',
#                                                                           'Weight',
#                                                                           'Memory_plusCapacite',
#                                                                           'width',
#                                                                           'height']),
#                                                                         ('cat_pipeline',
#                                                                          Pipeline(steps=[('inpute',
#                                                                                           SimpleImputer(strategy='most_frequent')),
#                                                                                          ('one-hot-encoder',
#                                                                                           OneHotEncoder(handle_unknown='ignore'))]),
#                                                                          ['Company',
#                                                                           'TypeName',
#                                                                           'Cpu',
#                                                                           'Gpu',
#                                                                           'OpSys',
#                                                                           'Mermory_plusType',
#                                                                           'Mermory_Type',
#                                                                           'IPS/Touchscreen'])])),
#                                        ('cls', ElasticNet(max_iter=10000))]),
#              param_grid={'cls__alpha': [0.01, 0.1, 1, 10, 100],
#                          'cls__l1_ratio': [0.1, 0.5, 0.7, 0.9, 1]})

# %%
grid.fit(X_train, y_train)
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:589: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 28733489403.05977, tolerance: 101170713.21856582
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:589: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 47601054375.32968, tolerance: 95346379.33399342
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:589: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 27499248012.974487, tolerance: 95188419.86920427
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:589: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 44798309377.18902, tolerance: 93051732.8854233
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:589: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 26273837001.161896, tolerance: 99014352.60986783
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:589: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 18414687649.758057, tolerance: 101170713.21856582
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:589: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 17143298301.304626, tolerance: 95346379.33399342
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:589: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 17805157466.734436, tolerance: 95188419.86920427
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:589: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 15467790750.519882, tolerance: 93051732.8854233
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:589: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7347374032.098297, tolerance: 99014352.60986783
#   model = cd_fast.sparse_enet_coordinate_descent(
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(transformers=[('num_pipeline',
#                                                                          Pipeline(steps=[('inpute',
#                                                                                           SimpleImputer()),
#                                                                                          ('scale',
#                                                                                           StandardScaler())]),
#                                                                          ['Inches',
#                                                                           'Ram',
#                                                                           'Memory',
#                                                                           'Weight',
#                                                                           'Memory_plusCapacite',
#                                                                           'width',
#                                                                           'height']),
#                                                                         ('cat_pipeline',
#                                                                          Pipeline(steps=[('inpute',
#                                                                                           SimpleImputer(strategy='most_frequent')),
#                                                                                          ('one-hot-encoder',
#                                                                                           OneHotEncoder(handle_unknown='ignore'))]),
#                                                                          ['Company',
#                                                                           'TypeName',
#                                                                           'Cpu',
#                                                                           'Gpu',
#                                                                           'OpSys',
#                                                                           'Mermory_plusType',
#                                                                           'Mermory_Type',
#                                                                           'IPS/Touchscreen'])])),
#                                        ('cls', ElasticNet(max_iter=10000))]),
#              param_grid={'cls__alpha': [0.01, 0.1, 1, 10, 100],
#                          'cls__l1_ratio': [0.1, 0.5, 0.7, 0.9, 1]})

# %%
best_model = grid.best_estimator_

# %%
y_pred = best_model.predict(X_test)

# %%
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)

# %%
eval_ElasticNet=[mse , rmse ,r2 , mae]

# %% [markdown]
# **Model Lasso() 'ls'**

# %%
#Create Pipepline with model lasso
pipeline = Pipeline(steps=[
    ('preprocessor', preprocessor),
    
    ('cls', models['rd'])])

# %%
pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num_pipeline',
#                                                   Pipeline(steps=[('inpute',
#                                                                    SimpleImputer()),
#                                                                   ('scale',
#                                                                    StandardScaler())]),
#                                                   ['Inches', 'Ram', 'Memory',
#                                                    'Weight',
#                                                    'Memory_plusCapacite',
#                                                    'width', 'height']),
#                                                  ('cat_pipeline',
#                                                   Pipeline(steps=[('inpute',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('one-hot-encoder',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['Company', 'TypeName', 'Cpu',
#                                                    'Gpu', 'OpSys',
#                                                    'Mermory_plusType',
#                                                    'Mermory_Type',
#                                                    'IPS/Touchscreen'])])),
#                 ('cls', Ridge())])

# %%
param_grid = param_grids['rd']

# %%
grid = GridSearchCV(pipeline, param_grid=param_grid, cv=5)

# %%
grid.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(transformers=[('num_pipeline',
#                                                                          Pipeline(steps=[('inpute',
#                                                                                           SimpleImputer()),
#                                                                                          ('scale',
#                                                                                           StandardScaler())]),
#                                                                          ['Inches',
#                                                                           'Ram',
#                                                                           'Memory',
#                                                                           'Weight',
#                                                                           'Memory_plusCapacite',
#                                                                           'width',
#                                                                           'height']),
#                                                                         ('cat_pipeline',
#                                                                          Pipeline(steps=[('inpute',
#                                                                                           SimpleImputer(strategy='most_frequent')),
#                                                                                          ('one-hot-encoder',
#                                                                                           OneHotEncoder(handle_unknown='ignore'))]),
#                                                                          ['Company',
#                                                                           'TypeName',
#                                                                           'Cpu',
#                                                                           'Gpu',
#                                                                           'OpSys',
#                                                                           'Mermory_plusType',
#                                                                           'Mermory_Type',
#                                                                           'IPS/Touchscreen'])])),
#                                        ('cls', Ridge())]),
#              param_grid={'cls__alpha': [0.01, 0.1, 1, 10]})

# %%
best_model = grid.best_estimator_

# %%
y_pred = best_model.predict(X_test)

# %%
# Evalution Model
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)

# %%
eval_Lasso=[mse , rmse ,r2 , mae]

# %% [markdown]
# **Model SVR() 'svr'**

# %%
#Create Pipepline with model SVR
pipeline = Pipeline(steps=[
    ('preprocessor', preprocessor),
    
    ('cls', models['svr'])])

# %%
pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num_pipeline',
#                                                   Pipeline(steps=[('inpute',
#                                                                    SimpleImputer()),
#                                                                   ('scale',
#                                                                    StandardScaler())]),
#                                                   ['Inches', 'Ram', 'Memory',
#                                                    'Weight',
#                                                    'Memory_plusCapacite',
#                                                    'width', 'height']),
#                                                  ('cat_pipeline',
#                                                   Pipeline(steps=[('inpute',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('one-hot-encoder',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['Company', 'TypeName', 'Cpu',
#                                                    'Gpu', 'OpSys',
#                                                    'Mermory_plusType',
#                                                    'Mermory_Type',
#                                                    'IPS/Touchscreen'])])),
#                 ('cls', SVR())])

# %%
param_grid = param_grids['svr']

# %%
grid = GridSearchCV(pipeline, param_grid=param_grid, cv=5)

# %%
grid.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(transformers=[('num_pipeline',
#                                                                          Pipeline(steps=[('inpute',
#                                                                                           SimpleImputer()),
#                                                                                          ('scale',
#                                                                                           StandardScaler())]),
#                                                                          ['Inches',
#                                                                           'Ram',
#                                                                           'Memory',
#                                                                           'Weight',
#                                                                           'Memory_plusCapacite',
#                                                                           'width',
#                                                                           'height']),
#                                                                         ('cat_pipeline',
#                                                                          Pipeline(steps=[('inpute',
#                                                                                           SimpleImputer(strategy='most_frequent')),
#                                                                                          ('one-hot-encoder',
#                                                                                           OneHotEncoder(handle_unknown='ignore'))]),
#                                                                          ['Company',
#                                                                           'TypeName',
#                                                                           'Cpu',
#                                                                           'Gpu',
#                                                                           'OpSys',
#                                                                           'Mermory_plusType',
#                                                                           'Mermory_Type',
#                                                                           'IPS/Touchscreen'])])),
#                                        ('cls', SVR())]),
#              param_grid={'cls__C': [1, 2, 3], 'cls__epsilon': [0.5, 1.0, 1.5]})

# %%
best_model = grid.best_estimator_

# %%
y_pred = best_model.predict(X_test)

# %%
# Evalution Model
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)

# %%
eval_SVR=[mse , rmse ,r2 , mae]

# %% [markdown]
# **Model DecisionTreeRegressor() 'dtg'**

# %%
#Create Pipepline with model DecisionTreeRegressor()
pipeline = Pipeline(steps=[
    ('preprocessor', preprocessor),
    
    ('cls', models['dtg'])])

# %%
pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num_pipeline',
#                                                   Pipeline(steps=[('inpute',
#                                                                    SimpleImputer()),
#                                                                   ('scale',
#                                                                    StandardScaler())]),
#                                                   ['Inches', 'Ram', 'Memory',
#                                                    'Weight',
#                                                    'Memory_plusCapacite',
#                                                    'width', 'height']),
#                                                  ('cat_pipeline',
#                                                   Pipeline(steps=[('inpute',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('one-hot-encoder',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['Company', 'TypeName', 'Cpu',
#                                                    'Gpu', 'OpSys',
#                                                    'Mermory_plusType',
#                                                    'Mermory_Type',
#                                                    'IPS/Touchscreen'])])),
#                 ('cls', DecisionTreeRegressor())])

# %%
param_grid = param_grids['dtg']

# %%
grid = GridSearchCV(pipeline, param_grid=param_grid, cv=5)

# %%
grid.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(transformers=[('num_pipeline',
#                                                                          Pipeline(steps=[('inpute',
#                                                                                           SimpleImputer()),
#                                                                                          ('scale',
#                                                                                           StandardScaler())]),
#                                                                          ['Inches',
#                                                                           'Ram',
#                                                                           'Memory',
#                                                                           'Weight',
#                                                                           'Memory_plusCapacite',
#                                                                           'width',
#                                                                           'height']),
#                                                                         ('cat_pipeline',
#                                                                          Pipeline(steps=[('inpute',
#                                                                                           SimpleImputer(strategy='most_frequent')),
#                                                                                          ('one-hot-encoder',
#                                                                                           OneHotEncoder(handle_unknown='ignore'))]),
#                                                                          ['Company',
#                                                                           'TypeName',
#                                                                           'Cpu',
#                                                                           'Gpu',
#                                                                           'OpSys',
#                                                                           'Mermory_plusType',
#                                                                           'Mermory_Type',
#                                                                           'IPS/Touchscreen'])])),
#                                        ('cls', DecisionTreeRegressor())]),
#              param_grid={'cls__max_depth': [3, 5, 10, None],
#                          'cls__min_samples_split': [2, 5, 10]})

# %%
best_model = grid.best_estimator_

# %%
y_pred = best_model.predict(X_test)

# %%
# Evalution Model
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)

# %%
eval_DecisionTreeRegressor=[mse , rmse ,r2 , mae]

# %% [markdown]
# **Model RandomForestRegressor() 'rfr'**

# %%
#Create Pipepline with model RandomForestRegressor
pipeline = Pipeline(steps=[
    ('preprocessor', preprocessor),
    
    ('cls', models['rfr'])])

# %%
pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num_pipeline',
#                                                   Pipeline(steps=[('inpute',
#                                                                    SimpleImputer()),
#                                                                   ('scale',
#                                                                    StandardScaler())]),
#                                                   ['Inches', 'Ram', 'Memory',
#                                                    'Weight',
#                                                    'Memory_plusCapacite',
#                                                    'width', 'height']),
#                                                  ('cat_pipeline',
#                                                   Pipeline(steps=[('inpute',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('one-hot-encoder',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['Company', 'TypeName', 'Cpu',
#                                                    'Gpu', 'OpSys',
#                                                    'Mermory_plusType',
#                                                    'Mermory_Type',
#                                                    'IPS/Touchscreen'])])),
#                 ('cls', RandomForestRegressor())])

# %%
param_grid = param_grids['rfr']

# %%
grid = GridSearchCV(pipeline, param_grid=param_grid, cv=5)

# %%
grid.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(transformers=[('num_pipeline',
#                                                                          Pipeline(steps=[('inpute',
#                                                                                           SimpleImputer()),
#                                                                                          ('scale',
#                                                                                           StandardScaler())]),
#                                                                          ['Inches',
#                                                                           'Ram',
#                                                                           'Memory',
#                                                                           'Weight',
#                                                                           'Memory_plusCapacite',
#                                                                           'width',
#                                                                           'height']),
#                                                                         ('cat_pipeline',
#                                                                          Pipeline(steps=[('inpute',
#                                                                                           SimpleImputer(strategy='most_frequent')),
#                                                                                          ('one-hot-encoder',
#                                                                                           OneHotEncoder(handle_unknown='ignore'))]),
#                                                                          ['Company',
#                                                                           'TypeName',
#                                                                           'Cpu',
#                                                                           'Gpu',
#                                                                           'OpSys',
#                                                                           'Mermory_plusType',
#                                                                           'Mermory_Type',
#                                                                           'IPS/Touchscreen'])])),
#                                        ('cls', RandomForestRegressor())]),
#              param_grid={'cls__max_depth': [None, 10, 20, 30],
#                          'cls__min_samples_split': [2, 5, 10],
#                          'cls__n_estimators': [50, 100, 200]})

# %%
best_model = grid.best_estimator_

# %%
y_pred = best_model.predict(X_test)

# %%
# Evalution Model
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)

# %%
eval_RandomForestRegressor=[mse , rmse ,r2 , mae]

# %% [markdown]
# **Model GradientBoostingRegressor() 'gbr'**

# %%
#Create Pipepline with model GradientBoostingRegressor
pipeline = Pipeline(steps=[
    ('preprocessor', preprocessor),
    
    ('cls', models['gbr'])])

# %%
pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num_pipeline',
#                                                   Pipeline(steps=[('inpute',
#                                                                    SimpleImputer()),
#                                                                   ('scale',
#                                                                    StandardScaler())]),
#                                                   ['Inches', 'Ram', 'Memory',
#                                                    'Weight',
#                                                    'Memory_plusCapacite',
#                                                    'width', 'height']),
#                                                  ('cat_pipeline',
#                                                   Pipeline(steps=[('inpute',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('one-hot-encoder',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['Company', 'TypeName', 'Cpu',
#                                                    'Gpu', 'OpSys',
#                                                    'Mermory_plusType',
#                                                    'Mermory_Type',
#                                                    'IPS/Touchscreen'])])),
#                 ('cls', GradientBoostingRegressor())])

# %%
param_grid = param_grids['gbr']

# %%
grid = GridSearchCV(pipeline, param_grid=param_grid, cv=5)

# %%
grid.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(transformers=[('num_pipeline',
#                                                                          Pipeline(steps=[('inpute',
#                                                                                           SimpleImputer()),
#                                                                                          ('scale',
#                                                                                           StandardScaler())]),
#                                                                          ['Inches',
#                                                                           'Ram',
#                                                                           'Memory',
#                                                                           'Weight',
#                                                                           'Memory_plusCapacite',
#                                                                           'width',
#                                                                           'height']),
#                                                                         ('cat_pipeline',
#                                                                          Pipeline(steps=[('inpute',
#                                                                                           SimpleImputer(strategy='most_frequent')),
#                                                                                          ('one-hot-encoder',
#                                                                                           OneHotEncoder(handle_unknown='ignore'))]),
#                                                                          ['Company',
#                                                                           'TypeName',
#                                                                           'Cpu',
#                                                                           'Gpu',
#                                                                           'OpSys',
#                                                                           'Mermory_plusType',
#                                                                           'Mermory_Type',
#                                                                           'IPS/Touchscreen'])])),
#                                        ('cls', GradientBoostingRegressor())]),
#              param_grid={'cls__learning_rate': [0.01, 0.1, 0.2],
#                          'cls__max_depth': [3, 5, 10],
#                          'cls__n_estimators': [50, 100, 200]})

# %%
best_model = grid.best_estimator_

# %%
y_pred = best_model.predict(X_test)

# %%
# Evalution Model
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)

# %%
eval_GradientBoostingRegressor=[mse , rmse ,r2 , mae]

# %%
evalution_table = pd.DataFrame(
    [eval_linearRegression, eval_ridge, eval_ElasticNet,
     eval_Lasso, eval_SVR, eval_DecisionTreeRegressor,
     eval_RandomForestRegressor, eval_GradientBoostingRegressor], 
    index=['eval_linearRegression', 'eval_ridge', 'eval_ElasticNet',
           'eval_Lasso', 'eval_SVR', 'eval_DecisionTreeRegressor',
           'eval_RandomForestRegressor', 'eval_GradientBoostingRegressor'],
    columns=['MSE', 'RMSE', 'R²', 'MAE']
)

# %%
pd.options.display.float_format = '{:.2f}'.format

# %%
evalution_table
# Out:
#                                          MSE     RMSE    R²      MAE
# eval_linearRegression           348920196.99 18679.41  0.77 13174.24
# eval_ridge                      371755603.87 19280.96  0.76 13478.15
# eval_ElasticNet                 363857859.93 19075.06  0.76 13369.09
# eval_Lasso                      371755603.87 19280.96  0.76 13478.15
# eval_SVR                       1605626681.55 40070.27 -0.06 27922.14
# eval_DecisionTreeRegressor      516223482.71 22720.55  0.66 13848.25
# eval_RandomForestRegressor      296242606.43 17211.70  0.81 10875.05
# eval_GradientBoostingRegressor  228230634.81 15107.30  0.85 10102.83

# %% [markdown]
# Let's evaluate the models based on the provided metrics:
#
# Metrics Explanation:
# MSE (Mean Squared Error): Measures the average squared difference between actual and predicted values. Lower is better.
# RMSE (Root Mean Squared Error): Square root of MSE; interpretable in the same units as the target variable. Lower is better.
# R² (Coefficient of Determination): Measures how well the model explains the variance in the target variable. Values closer to 1 are better, and negative values indicate poor performance.
# MAE (Mean Absolute Error): Measures the average absolute difference between actual and predicted values. Lower is better.

# %% [markdown]
# # Recommended Model:
# Gradient Boosting Regressor is the clear winner:
# Best R² (0.85), indicating it explains 85% of the variance in the target variable.
# Lowest MSE, RMSE, and MAE among all models.
# If computational efficiency and interpretability are priorities, Random Forest Regressor is also a strong candidate, performing slightly worse but still reliable.

# %% [markdown]
# # Saving the model for creating an application.

# %%
import pickle
with open('model_GradientBoostingRegressor.pkl', 'wb') as f:
    pickle.dump(best_model, f)

# %% [markdown]
# # In the end, this equation combines the previous steps into a single code implementation.

# %%
def train_and_evaluate(models, param_grids, X_train, y_train, X_test, y_test):
    best_models = {}
    results = []

    for model_name in models:
        model = models[model_name]
        param_grid = param_grids.get(model_name, {})
        
        
        pipeline = Pipeline(steps=[('preprocessor', preprocessor), ('cls', model)])
        
        grid_search = GridSearchCV(pipeline, param_grid=param_grid, cv=5, n_jobs=-1, error_score='raise')
        try:
            grid_search.fit(X_train, y_train)
        except ValueError as e:
            print(f"Error in model {model_name}: {e}")
            continue
        
    
        best_params = grid_search.best_params_
        
        best_model = grid_search.best_estimator_

        y_pred = best_model.predict(X_test)

        mse = mean_squared_error(y_test, y_pred)
        rmse = np.sqrt(mse)
        r2 = r2_score(y_test, y_pred)
        mae = mean_absolute_error(y_test, y_pred)

        results.append({
            'Model': model_name,
            'Best Params': best_params,
            'MSE': mse,
            'RMSE': rmse,
            'R2': r2,
            'MAE': mae
        })
        
        best_models[model_name] = best_model

    return results, best_models

# %%
results, best_models = train_and_evaluate(models, param_grids, X_train, y_train, X_test, y_test)

for result in results:
    print(f"Model: {result['Model']}")
    print(f"Best Params: {result['Best Params']}")
    print(f"MSE: {result['MSE']}")
    print(f"RMSE: {result['RMSE']}")
    print(f"R2: {result['R2']}")
    print(f"MAE: {result['MAE']}")
    print("="*50)
# Out:
# Model: lg
# Best Params: {}
# MSE: 348920196.9923889
# RMSE: 18679.405691627046
# R2: 0.7704620362395747
# MAE: 13174.2416143293
# ==================================================
# Model: rd
# Best Params: {'cls__alpha': 10}
# MSE: 371755603.87114125
# RMSE: 19280.96480654278
# R2: 0.7554397106712328
# MAE: 13478.145351958252
# ==================================================
# Model: ls
# Best Params: {'cls__alpha': 10}
# MSE: 351181764.11233866
# RMSE: 18739.844292638576
# R2: 0.7689742590455474
# MAE: 13171.621830321343
# ==================================================
# Model: en
# Best Params: {'cls__alpha': 0.01, 'cls__l1_ratio': 0.5}
# MSE: 363857859.9255298
# RMSE: 19075.058582492737
# R2: 0.7606352599091477
# MAE: 13369.091153991369
# ==================================================
# Model: svr
# Best Params: {'cls__C': 3, 'cls__epsilon': 0.5}
# MSE: 1605626681.552376
# RMSE: 40070.27179284383
# R2: -0.05626524981865866
# MAE: 27922.137332805112
# ==================================================
# Model: dtg
# Best Params: {'cls__max_depth': None, 'cls__min_samples_split': 10}
# MSE: 512587386.03091484
# RMSE: 22640.39279762864
# R2: 0.6627931949683561
# MAE: 13459.993118348557
# ==================================================
# Model: rfr
# Best Params: {'cls__max_depth': 30, 'cls__min_samples_split': 2, 'cls__n_estimators': 50}
# MSE: 300862719.322276
# RMSE: 17345.394758329254
# R2: 0.8020767597865193
# MAE: 11043.52753602689
# ==================================================
# Model: gbr
# Best Params: {'cls__learning_rate': 0.1, 'cls__max_depth': 3, 'cls__n_estimators': 200}
# MSE: 232403002.51752084
# RMSE: 15244.769677417919
# R2: 0.8471131438377459
# MAE: 10101.373024499519
# ==================================================
